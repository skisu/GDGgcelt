# %%
import pandas as pd
import numpy as np
df = pd.read_csv('matches.csv')
df
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
df.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
df.tail()
# Out:
#            id season       city        date   match_type  player_of_match  \
# 1090  1426307   2024  Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309   2024  Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310   2024  Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311   2024    Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312   2024    Chennai  2024-05-26        Final         MA Starc
#
#                                                   venue  \
# 1090  Rajiv Gandhi International Stadium, Uppal, Hyd...
# 1091                   Narendra Modi Stadium, Ahmedabad
# 1092                   Narendra Modi Stadium, Ahmedabad
# 1093           MA Chidambaram Stadium, Chepauk, Chennai
# 1094           MA Chidambaram Stadium, Chepauk, Chennai
#
#                             team1                  team2          toss_winner  \
# 1090                 Punjab Kings    Sunrisers Hyderabad         Punjab Kings
# ...

# %%
df.describe()
# Out:
#                  id  result_margin  target_runs  target_overs
# count  1.095000e+03    1076.000000  1092.000000   1092.000000
# mean   9.048283e+05      17.259294   165.684066     19.759341
# std    3.677402e+05      21.787444    33.427048      1.581108
# min    3.359820e+05       1.000000    43.000000      5.000000
# 25%    5.483315e+05       6.000000   146.000000     20.000000
# 50%    9.809610e+05       8.000000   166.000000     20.000000
# 75%    1.254062e+06      20.000000   187.000000     20.000000
# max    1.426312e+06     146.000000   288.000000     20.000000

# %%
df.describe(include = 'all')
# Out:
#                   id season    city        date match_type player_of_match  \
# count   1.095000e+03   1095    1044        1095       1095            1090
# unique           NaN     17      36         823          8             291
# top              NaN   2013  Mumbai  2008-04-26     League  AB de Villiers
# freq             NaN     76     173           2       1029              25
# mean    9.048283e+05    NaN     NaN         NaN        NaN             NaN
# std     3.677402e+05    NaN     NaN         NaN        NaN             NaN
# min     3.359820e+05    NaN     NaN         NaN        NaN             NaN
# 25%     5.483315e+05    NaN     NaN         NaN        NaN             NaN
# 50%     9.809610e+05    NaN     NaN         NaN        NaN             NaN
# 75%     1.254062e+06    NaN     NaN         NaN        NaN             NaN
# max     1.426312e+06    NaN     NaN         NaN        NaN             NaN
#
#                venue                        team1           team2  \
# ...

# %%
df.dtypes
# Out:
# id                   int64
# season              object
# city                object
# date                object
# match_type          object
# player_of_match     object
# venue               object
# team1               object
# team2               object
# toss_winner         object
# toss_decision       object
# winner              object
# result              object
# result_margin      float64
# target_runs        float64
# target_overs       float64
# super_over          object
# method              object
# umpire1             object
# umpire2             object
# dtype: object

# %%
df.isnull().sum()
# Out:
# id                    0
# season                0
# city                 51
# date                  0
# match_type            0
# player_of_match       5
# venue                 0
# team1                 0
# team2                 0
# toss_winner           0
# toss_decision         0
# winner                5
# result                0
# result_margin        19
# target_runs           3
# target_overs          3
# super_over            0
# method             1074
# umpire1               0
# umpire2               0
# dtype: int64

# %%
print("no of rows : ",len(df))
print("no of columns : ",len(df.columns))
# Out:
# no of rows :  1095
# no of columns :  20

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1044 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
# ...

# %%
df[df['season'] == '2024']
# Out:
#            id season       city        date   match_type    player_of_match  \
# 1024  1422119   2024    Chennai  2024-03-22       League  Mustafizur Rahman
# 1025  1422120   2024     Mohali  2024-03-23       League          SM Curran
# 1026  1422121   2024    Kolkata  2024-03-23       League         AD Russell
# 1027  1422122   2024     Jaipur  2024-03-24       League          SV Samson
# 1028  1422123   2024  Ahmedabad  2024-03-24       League    B Sai Sudharsan
# ...       ...    ...        ...         ...          ...                ...
# 1090  1426307   2024  Hyderabad  2024-05-19       League    Abhishek Sharma
# 1091  1426309   2024  Ahmedabad  2024-05-21  Qualifier 1           MA Starc
# 1092  1426310   2024  Ahmedabad  2024-05-22   Eliminator           R Ashwin
# 1093  1426311   2024    Chennai  2024-05-24  Qualifier 2      Shahbaz Ahmed
# 1094  1426312   2024    Chennai  2024-05-26        Final           MA Starc
#
# ...

# %%
len(df[df['season'] == '2024'])
# Out:
# 71

# %%
df[df['id'] == 1426307]
# Out:
#            id season       city        date match_type  player_of_match  \
# 1090  1426307   2024  Hyderabad  2024-05-19     League  Abhishek Sharma
#
#                                                   venue         team1  \
# 1090  Rajiv Gandhi International Stadium, Uppal, Hyd...  Punjab Kings
#
#                     team2   toss_winner toss_decision               winner  \
# 1090  Sunrisers Hyderabad  Punjab Kings           bat  Sunrisers Hyderabad
#
#        result  result_margin  target_runs  target_overs super_over method  \
# 1090  wickets            4.0        215.0          20.0          N    NaN
#
#           umpire1    umpire2
# 1090  Nitin Menon  VK Sharma

# %%
df[df['id'] == 1426307]['venue']
# Out:
# 1090    Rajiv Gandhi International Stadium, Uppal, Hyd...
# Name: venue, dtype: object

# %%
df[df['city'] == 'Bangalore']
# Out:
#           id   season       city        date   match_type  player_of_match  \
# 0     335982  2007/08  Bangalore  2008-04-18       League      BB McCullum
# 10    335992  2007/08  Bangalore  2008-04-26       League        SR Watson
# 14    335996  2007/08  Bangalore  2008-04-28       League         MS Dhoni
# 21    336034  2007/08  Bangalore  2008-05-03       League          P Kumar
# 24    336006  2007/08  Bangalore  2008-05-05       League      S Sreesanth
# ..       ...      ...        ...         ...          ...              ...
# 606  1082621     2017  Bangalore  2017-04-27       League           AJ Tye
# 618  1082633     2017  Bangalore  2017-05-05       League   Sandeep Sharma
# 621  1082636     2017  Bangalore  2017-05-07       League        SP Narine
# 633  1082648     2017  Bangalore  2017-05-17   Eliminator  NM Coulter-Nile
# 634  1082649     2017  Bangalore  2017-05-19  Qualifier 2        KV Sharma
#
#                      venue                        team1  \
# ...

# %%
df[df['match_type']=='Eliminator']
# Out:
#            id   season           city        date  match_type  \
# 395    598071     2013          Delhi  2013-05-22  Eliminator
# 455    734045     2014         Mumbai  2014-05-28  Eliminator
# 514    829819     2015           Pune  2015-05-20  Eliminator
# 633   1082648     2017      Bangalore  2017-05-17  Eliminator
# 693   1136618     2018        Kolkata  2018-05-23  Eliminator
# 753   1181766     2019  Visakhapatnam  2019-05-08  Eliminator
# 813   1237178  2020/21      Abu Dhabi  2020-11-06  Eliminator
# 873   1254115     2021        Sharjah  2021-10-11  Eliminator
# 947   1312198     2022        Kolkata  2022-05-25  Eliminator
# 1021  1370351     2023        Chennai  2023-05-24  Eliminator
# 1092  1426310     2024      Ahmedabad  2024-05-22  Eliminator
#
#       player_of_match                                              venue  \
# 395          BJ Hodge                                   Feroz Shah Kotla
# ...

# %%
df[df['player_of_match'] == 'MA Starc']
# Out:
#            id season       city        date   match_type player_of_match  \
# 479    829749   2015  Ahmedabad  2015-04-24       League        MA Starc
# 1091  1426309   2024  Ahmedabad  2024-05-21  Qualifier 1        MA Starc
# 1094  1426312   2024    Chennai  2024-05-26        Final        MA Starc
#
#                                          venue                team1  \
# 479               Sardar Patel Stadium, Motera     Rajasthan Royals
# 1091          Narendra Modi Stadium, Ahmedabad  Sunrisers Hyderabad
# 1094  MA Chidambaram Stadium, Chepauk, Chennai  Sunrisers Hyderabad
#
#                             team2                  toss_winner toss_decision  \
# 479   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1091        Kolkata Knight Riders          Sunrisers Hyderabad           bat
# 1094        Kolkata Knight Riders          Sunrisers Hyderabad           bat
#
#                            winner   result  result_margin  target_runs  \
# ...

# %%
len(df[df['player_of_match'] == 'MA Starc'])
# Out:
# 3

# %%
df[df['venue'] == 'Punjab Cricket Association Stadium, Mohali']
# Out:
#          id   season        city        date match_type player_of_match  \
# 1    335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 9    335991  2007/08  Chandigarh  2008-04-25     League   KC Sangakkara
# 13   335995  2007/08  Chandigarh  2008-04-27     League       SM Katich
# 20   336003  2007/08  Chandigarh  2008-05-03     League       IK Pathan
# 33   336016  2007/08  Chandigarh  2008-05-12     League        SE Marsh
# 46   336031  2007/08  Chandigarh  2008-05-23     League        SE Marsh
# 54   336019  2007/08  Chandigarh  2008-05-28     League        SE Marsh
# 117  419108  2009/10  Chandigarh  2010-03-13     League       G Gambhir
# 133  419124  2009/10  Chandigarh  2010-03-24     League        AC Voges
# 137  419127  2009/10  Chandigarh  2010-03-27     League       MK Tiwary
# 145  419136  2009/10  Chandigarh  2010-04-02     League    KP Pietersen
# 155  419146  2009/10  Chandigarh  2010-04-09     League   KC Sangakkara
# ...

# %%
len(df[df['winner'] == 'Mumbai Indians'])
# Out:
# 144

# %%
df['umpire1'].value_counts().head(10)
# Out:
# umpire1
# AK Chaudhary             115
# HDPK Dharmasena           79
# KN Ananthapadmanabhan     59
# CB Gaffaney               53
# Asad Rauf                 51
# Nitin Menon               50
# S Ravi                    48
# M Erasmus                 42
# Aleem Dar                 38
# BF Bowden                 36
# Name: count, dtype: int64

# %%
df['umpire2'].value_counts().head(10)
# Out:
# umpire2
# S Ravi           83
# VK Sharma        61
# C Shamshuddin    60
# Nitin Menon      54
# SJA Taufel       54
# RJ Tucker        53
# VA Kulkarni      44
# CK Nandan        43
# YC Barde         36
# RB Tiffin        30
# Name: count, dtype: int64

# %%
df[df['toss_decision']=='bat']['winner'].value_counts().head(5)
# Out:
# winner
# Chennai Super Kings            63
# Mumbai Indians                 54
# Kolkata Knight Riders          50
# Rajasthan Royals               43
# Royal Challengers Bangalore    37
# Name: count, dtype: int64

# %%
df[df['toss_decision']=='field']['winner'].value_counts().head(5)
# Out:
# winner
# Mumbai Indians                 90
# Kolkata Knight Riders          81
# Royal Challengers Bangalore    79
# Chennai Super Kings            75
# Rajasthan Royals               69
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# id                    0
# season                0
# city                 51
# date                  0
# match_type            0
# player_of_match       5
# venue                 0
# team1                 0
# team2                 0
# toss_winner           0
# toss_decision         0
# winner                5
# result                0
# result_margin        19
# target_runs           3
# target_overs          3
# super_over            0
# method             1074
# umpire1               0
# umpire2               0
# dtype: int64

# %%
df_to_null_replace = df.replace(to_replace = [np.nan] , value = [1])
df_to_null_replace
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
df_to_null_replace.isnull().sum()
# Out:
# id                 0
# season             0
# city               0
# date               0
# match_type         0
# player_of_match    0
# venue              0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# winner             0
# result             0
# result_margin      0
# target_runs        0
# target_overs       0
# super_over         0
# method             0
# umpire1            0
# umpire2            0
# dtype: int64

# %%
df[(df['target_runs'] >= 150) & (df['target_runs'] <= 200)]
# Out:
#            id   season        city        date   match_type player_of_match  \
# 3      335985  2007/08      Mumbai  2008-04-20       League      MV Boucher
# 5      335987  2007/08      Jaipur  2008-04-21       League       SR Watson
# 9      335991  2007/08  Chandigarh  2008-04-25       League   KC Sangakkara
# 12     335994  2007/08      Mumbai  2008-04-27       League    AC Gilchrist
# 13     335995  2007/08  Chandigarh  2008-04-27       League       SM Katich
# ...       ...      ...         ...         ...          ...             ...
# 1083  1426298     2024     Kolkata  2024-05-11       League        CV Varun
# 1085  1426300     2024   Bengaluru  2024-05-12       League         C Green
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1        MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator        R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2   Shahbaz Ahmed
#
# ...

# %%
len(df[(df['target_runs'] >= 150) & (df['target_runs'] <= 200)])
# Out:
# 636

# %%
df['target_runs'].max()
# Out:
# np.float64(288.0)

# %%
df['target_runs'].min()
# Out:
# np.float64(43.0)

# %%
df['target_runs'].mean()
# Out:
# np.float64(165.68406593406593)

# %%
df_to_null_replace2 = df.replace(to_replace = ['N'] , value = [0])
df_to_null_replace2
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
df['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 144
# Chennai Super Kings            138
# Kolkata Knight Riders          131
# Royal Challengers Bangalore    116
# Rajasthan Royals               112
# Sunrisers Hyderabad             88
# Kings XI Punjab                 88
# Delhi Daredevils                67
# Delhi Capitals                  48
# Deccan Chargers                 29
# Gujarat Titans                  28
# Punjab Kings                    24
# Lucknow Super Giants            24
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Royal Challengers Bengaluru      7
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
df.sort_index(axis =0 , ascending =False)
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# ...       ...      ...         ...         ...          ...              ...
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
#
# ...

# %%
df.sort_index(axis =1 , ascending =False)
# Out:
#                            winner  \
# 0           Kolkata Knight Riders
# 1             Chennai Super Kings
# 2                Delhi Daredevils
# 3     Royal Challengers Bangalore
# 4           Kolkata Knight Riders
# ...                           ...
# 1090          Sunrisers Hyderabad
# 1091        Kolkata Knight Riders
# 1092             Rajasthan Royals
# 1093          Sunrisers Hyderabad
# 1094        Kolkata Knight Riders
#
#                                                   venue               umpire2  \
# 0                                 M Chinnaswamy Stadium           RE Koertzen
# 1            Punjab Cricket Association Stadium, Mohali            SL Shastri
# 2                                      Feroz Shah Kotla        GA Pratapkumar
# 3                                      Wankhede Stadium             DJ Harper
# 4                                          Eden Gardens           K Hariharan
# ...                                                 ...                   ...
# ...

# %%
df['city'].value_counts().head()
# Out:
# city
# Mumbai       173
# Kolkata       93
# Delhi         90
# Chennai       85
# Hyderabad     77
# Name: count, dtype: int64

# %%
df['date']
# Out:
# 0       2008-04-18
# 1       2008-04-19
# 2       2008-04-19
# 3       2008-04-20
# 4       2008-04-20
#            ...
# 1090    2024-05-19
# 1091    2024-05-21
# 1092    2024-05-22
# 1093    2024-05-24
# 1094    2024-05-26
# Name: date, Length: 1095, dtype: object

# %%
df[df['date'].apply(lambda x: x[5:7] == '05')]
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 17     335999  2007/08   Hyderabad  2008-05-01       League         SE Marsh
# 18     336000  2007/08      Jaipur  2008-05-01       League      SA Asnodkar
# 19     336001  2007/08     Chennai  2008-05-02       League         V Sehwag
# 20     336003  2007/08  Chandigarh  2008-05-03       League        IK Pathan
# 21     336034  2007/08   Bangalore  2008-05-03       League          P Kumar
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
len(df[df['date'].apply(lambda x: x[5:7] == '05')])
# Out:
# 437

# %%
df[df['umpire1'] == "MR Benson"]['toss_winner'].value_counts()
# Out:
# toss_winner
# Kolkata Knight Riders    3
# Rajasthan Royals         2
# Deccan Chargers          2
# Chennai Super Kings      1
# Delhi Daredevils         1
# Kings XI Punjab          1
# Name: count, dtype: int64

# %%
df[df['umpire2'] == "GA Pratapkumar"]['toss_winner'].value_counts()
# Out:
# toss_winner
# Rajasthan Royals    2
# Mumbai Indians      2
# Deccan Chargers     1
# Delhi Daredevils    1
# Name: count, dtype: int64

# %%
df['date'].apply(lambda x: x[:4]).value_counts()
# Out:
# date
# 2013    76
# 2022    74
# 2012    74
# 2023    74
# 2011    73
# 2024    71
# 2019    60
# 2016    60
# 2010    60
# 2021    60
# 2020    60
# 2014    60
# 2018    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: count, dtype: int64

# %%
df['date']
# Out:
# 0       2008-04-18
# 1       2008-04-19
# 2       2008-04-19
# 3       2008-04-20
# 4       2008-04-20
#            ...
# 1090    2024-05-19
# 1091    2024-05-21
# 1092    2024-05-22
# 1093    2024-05-24
# 1094    2024-05-26
# Name: date, Length: 1095, dtype: object

# %%
df[df['date'].apply(lambda x: x[:7] == '2024-05')]
# Out:
#            id season        city        date   match_type  player_of_match  \
# 1072  1426287   2024     Chennai  2024-05-01       League    Harpreet Brar
# 1073  1426288   2024   Hyderabad  2024-05-02       League          B Kumar
# 1074  1426289   2024      Mumbai  2024-05-03       League          VR Iyer
# 1075  1426290   2024   Bengaluru  2024-05-04       League   Mohammed Siraj
# 1076  1426291   2024  Dharamsala  2024-05-05       League        RA Jadeja
# 1077  1426292   2024     Lucknow  2024-05-05       League        SP Narine
# 1078  1426293   2024      Mumbai  2024-05-06       League         SA Yadav
# 1079  1426294   2024       Delhi  2024-05-07       League    Kuldeep Yadav
# 1080  1426295   2024   Hyderabad  2024-05-08       League          TM Head
# 1081  1426296   2024  Dharamsala  2024-05-09       League          V Kohli
# 1082  1426297   2024   Ahmedabad  2024-05-10       League     Shubman Gill
# ...
